# %% [markdown]
# # ***Lesson 3 - Importing and Packages***

# %% [markdown]
# # PART 1 - Modules

# %% [markdown]
# ## 1.1 Importing is not "Including Code"
#
# In python, `import` does not copy code into your file.
#
# Instead, importing:
# - Finds a module
# - Loads it
# - Executes it
# - Binds a name to a module object
#
# This is a *runtime operation*, not a compile-time one.

# %% [markdown]
# ## 1.2 Every `.py` file is a Module
#
# Any file:
#
# ```text
# file.py
# ```
#
# is a *module* named `file`.
#
# -----
#
# <img src="https://www.askpython.com/wp-content/uploads/2019/12/Python-Module-Example-1.png" width="400">
# Example:

# %%
# We have a file in our directory named math_utils.py
import math_utils

print(math_utils.add(1, 2))
print(math_utils.sub(1, 2))
# Out:
# 3
# -1

# %% [markdown]
# Important:
# - `math_util` is a *module object*
# - Functions are attributes on that object

# %% [markdown]
# ## 1.3 What actually happens when you import
#
# When Python sees:
#
# ```python
# import math_util
# ```
#
# It performs these steps:
# 1. Check `sys.modules` (import cache)
# 2. If found then reuse it
# 3. If not found:
#     - Locate the module
#     - Create a module object
#     - Execute the file top-to-bottom
#     - Store it in `sys.modules`
# 4. Bind the name `math_util` to a module object
#
# This is why imports are fast after the first time and side effects only run once. So circular imports can partially work.

# %% [markdown]
# ### Proof of concept
#
# We have a file named `example.py` with `print("executing example")`. Reminder that if the module is not found, then we execute the file and then store it in `sys.modules`. So if we import the module twice, then it will only execute once.

# %%
import example
import example
# Out:
# executing example

# %% [markdown]
# ## 1.4 The Imp[ort Cache (`sys.modules`)
#
# Python keeps all loaded modules in a dictionary:

# %%
import sys
print(sys.modules.keys())
# Out:
# dict_keys(['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', '_io', 'marshal', 'posix', '_frozen_importlib_external', 'time', 'zipimport', '_codecs', 'codecs', 'encodings.aliases', 'encodings.cp437', 'encodings', 'encodings.utf_8', '_signal', 'encodings.latin_1', '_abc', 'abc', 'io', '__main__', '_stat', 'stat', '_collections_abc', 'genericpath', 'posixpath', 'os.path', 'os', '_sitebuiltins', '_locale', '_bootlocale', '__future__', '_virtualenv', 'site', 'importlib._bootstrap', 'importlib._bootstrap_external', 'types', 'warnings', 'importlib', 'importlib.machinery', '_heapq', 'heapq', 'itertools', 'keyword', '_operator', 'operator', 'reprlib', '_collections', 'collections', 'collections.abc', '_functools', 'functools', 'contextlib', 'enum', '_sre', 'sre_constants', 'sre_parse', 'sre_compile', 'copyreg', 're', 'typing.io', 'typing.re', 'typing', 'importlib.abc', 'importlib.util', '_weakrefset', 'weakref', 'pkgutil', 'runpy', 'fnmatch', 'ntpath', 'errno', 'urllib', 'urllib.parse', 'pathlib', 'ipykernel._version', '_json', 'json.scanner', 'json.decoder', 'json.encoder', 'json', 'signal', 'threading', 'pwd', 'grp', '_posixsubprocess', 'select', 'math', 'selectors', 'subprocess', 'jupyter_client._version', 'platform', 'zmq.backend.select', 'cython_runtime', '_cython_3_1_3amsendbackport', 'zmq.constants', 'zmq.error', 'zmq.backend.cython._zmq', 'zmq.backend.cython', 'zmq.backend', 'atexit', '_ast', 'ast', '_opcode', 'opcode', 'dis', 'token', 'tokenize', 'linecache', 'inspect', '_socket', 'typing_extensions', 'zmq._typing', 'zmq.utils', 'zmq.utils.interop', 'zmq.sugar.attrsettr', '_struct', 'struct', '_compat_pickle', '_pickle', 'pickle', '_bisect', 'bisect', '_random', '_sha512', 'random', 'zmq.utils.jsonapi', 'zmq.sugar.poll', 'zmq.sugar.socket', 'zmq.sugar.context', 'zmq.sugar.frame', 'zmq.sugar.tracker', 'zmq.sugar.version', 'zmq.sugar.stopwatch', 'zmq.sugar', 'zmq', 'concurrent', 'traceback', '_string', 'string', 'logging', 'concurrent.futures._base', 'concurrent.futures', 'array', 'socket', '_ssl', 'binascii', 'base64', 'ssl', 'asyncio.constants', 'asyncio.format_helpers', 'asyncio.base_futures', 'asyncio.log', 'asyncio.coroutines', '_contextvars', 'contextvars', 'asyncio.exceptions', 'asyncio.base_tasks', '_asyncio', 'asyncio.events', 'asyncio.futures', 'asyncio.protocols', 'asyncio.transports', 'asyncio.sslproto', 'asyncio.locks', 'asyncio.tasks', 'asyncio.staggered', 'asyncio.trsock', 'asyncio.base_events', 'asyncio.runners', 'asyncio.queues', 'asyncio.streams', 'asyncio.subprocess', 'asyncio.threads', 'asyncio.base_subprocess', 'asyncio.selector_events', 'asyncio.unix_events', 'asyncio', 'zmq._future', 'zmq.asyncio', 'traitlets.utils', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.warnings', 'traitlets.traitlets', 'traitlets._version', 'copy', 'traitlets.utils.decorators', 'traitlets', '_queue', 'queue', 'jupyter_core.version', 'jupyter_core', 'jupyter_core.utils', 'jupyter_client.channelsabc', '_hashlib', '_blake2', '_sha3', 'hashlib', 'hmac', 'pprint', '_datetime', 'datetime', 'tornado', 'numbers', 'logging.handlers', 'html.entities', 'html', 'zlib', 'tornado.speedups', 'tornado.util', 'tornado.escape', '_curses', 'curses', 'tornado.log', 'tornado.concurrent', 'tornado.ioloop', 'socketserver', 'logging.config', 'textwrap', 'traitlets.utils.text', 'gettext', 'argparse', 'traitlets.config.loader', 'traitlets.config.configurable', 'traitlets.utils.nested_update', 'traitlets.config.application', 'traitlets.config', 'traitlets.log', 'zmq.eventloop', 'zmq.eventloop.zmqstream', 'jupyter_client.adapter', 'dateutil._version', 'dateutil', 'locale', 'calendar', 'six', '_decimal', 'decimal', 'dateutil._common', 'dateutil.relativedelta', 'six.moves', 'dateutil.tz._common', 'dateutil.tz._factories', 'dateutil.tz.tz', 'dateutil.tz', 'dateutil.parser._parser', 'dateutil.parser.isoparser', ...

# %%
print(sys.modules["example"])
# Out:
# <module 'example' from '/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/1.1 Python installations/example.py'>

# %% [markdown]
# Since we already imported the `example` module we made, it is in the `sys.modules` cache.
#
# So now lets delete it from the cache.

# %%
del sys.modules["example"]

# %% [markdown]
# ## 1.5 How Python finds modules (`sys.path`)
#
# Python searches for modules using `sys.path`.
#
# Lets inspect it:

# %%
import sys
for p in sys.path:
    print(p)
# Out:
# /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals
# /Applications/PyCharm.app/Contents/plugins/python-ce/helpers/pydev
# /Applications/PyCharm.app/Contents/plugins/python-ce/helpers/jupyter_debug
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python39.zip
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9
# /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/lib-dynload
#
# /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages

# %% [markdown]
# Typically, the order will be:
# - Script directory
# - Current working directory
# - Standard lib
# - `site-packages` from our venv

# %% [markdown]
# # PART 2 - Packages

# %% [markdown]
# ## 2.1 What is a Package?
#
# A *package* is a directory that Python treats as a module.
#
# Structure:
#
# ```text
# my_app/
# ├── __init__.py
# ├── main.py
# └── utils.py
# ```
#
# Here is how to import from this **package**:
#
# ```python
# import my_app.utils
# ```
#
# -----
#
# ***IMPORTANT:**
# - `__init__.py` marks a directory as a package
# - The package itself is a module object
# - Submodules are attributes
#
# <img src="https://pythongeeks.org/wp-content/uploads/2021/12/structure-of-packages.webp" width="300">

# %% [markdown]
# ## 2.2 What does `__init__.py` do?
#
# `__init__.py`:
# - Executes when the package is imported
# - Defines the package's public API
#
# Example :
#
# We have a package `my_app` with the files `main.py` and `utils.py`.
#
# Lets say we want to import the `add` method from `utils.py`. If we keep our `__init__.py` empty, then this is how we would import it:

# %%
from my_app.utils import add

# %% [markdown]
# If we include this in our `__init__.py`, then we could import better
#
# ```python
# # my_app/__init__.py
# from .utils import add
# ```

# %%
from my_app import add

# %% [markdown]
# It is best practice to keep `__init__.py` lightweight and avoid heavy imports

# %% [markdown]
# # PART 3 - What is `pip`

# %% [markdown]
# ## 3.1 What isn't `pip`
#
# `pip` is not part of Python execution.
#
# `pip`:
# - Downloads packages
# - Installs files into directories
# - Knows nothing about imports at runtime
#
# Python:
# - Imports files based on `sys.path`
# - Does not know or care about `pip`

# %% [markdown]
# ## 3.2 What IS `pip`
#
# `pip` stands for **pip installs packages**
#
# When you run:
#
# ```bash
# pip install requests
# ```
#
# `pip`:
# 1. Downloads a package archive
# 2. Extracts files
# 3. Copies them into `site-packages`
# 4. Write metadata (`.dist-info`)
#
# Here is where it would copy the files:
#
# ```text
# venv/
# └── lib/
#     └── python3.12/
#         └── site-packages/
#             ├── requests/
#             └── requests-2.31.0.dist-info/
# ```

# %% [markdown]
# ## 3.3 `pip` vs `python -m pip`
#
# Its best practice to do:
#
# ```bash
# python -m pip install requests
# ```
#
# Because it guarantees the correct interpreter and avoids environment mismatch

# %%
# !python3 -m pip install requests
# Out:
# Requirement already satisfied: requests in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from requests) (2026.1.4)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## 3.4 Listing and Inspecting Packages

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------
# anyio                     4.12.1
# appnope                   0.1.4
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.4.0
# asttokens                 3.0.1
# async-lru                 2.0.5
# attrs                     25.4.0
# babel                     2.18.0
# beautifulsoup4            4.14.3
# bleach                    6.2.0
# certifi                   2026.1.4
# cffi                      2.0.0
# charset-normalizer        3.4.4
# comm                      0.2.3
# debugpy                   1.8.20
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.3.1
# executing                 2.2.1
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.11
# importlib_metadata        8.7.1
# ipykernel                 6.31.0
# ipython                   8.18.1
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# json5                     0.13.0
# jsonpointer               3.0.0
# jsonschema                4.25.1
# jsonschema-specifications 2025.9.1
# jupyter_client            8.6.3
# jupyter_core              5.8.1
# jupyter-events            0.12.0
# jupyter-lsp               2.3.0
# jupyter_server            2.17.0
# jupyter_server_terminals  0.5.4
# jupyterlab                4.5.3
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.28.0
# lark                      1.3.1
# MarkupSafe                3.0.3
# matplotlib-inline         0.2.1
# mistune                   3.2.0
# nbclient                  0.10.2
# nbconvert                 7.17.0
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.5.3
# notebook_shim             0.2.4
# overrides                 7.7.0
# packaging                 26.0
# pandocfilters             1.5.1
# parso                     0.8.6
# pexpect                   4.9.0
# pip                       24.3.1
# platformdirs              4.4.0
# prometheus_client         0.24.1
# prompt_toolkit            3.0.52
# psutil                    7.2.2
# ptyprocess                0.7.0
# pure_eval                 0.2.3
# pycparser                 2.23
# Pygments                  2.19.2
# python-dateutil           2.9.0.post0
# python-json-logger        4.0.0
# PyYAML                    6.0.3
# pyzmq                     27.1.0
# referencing               0.36.2
# requests                  2.32.5
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rfc3987-syntax            1.1.0
# rpds-py                   0.27.1
# Send2Trash                2.1.0
# setuptools                44.1.1
# six                       1.17.0
# soupsieve                 2.8.3
# stack-data                0.6.3
# terminado                 0.18.1
# tinycss2                  1.4.0
# tomli                     2.4.0
# tornado                   6.5.4
# traitlets                 5.14.3
# typing_extensions         4.15.0
# tzdata                    2025.3
# uri-template              1.3.0
# urllib3                   2.6.3
# wcwidth                   0.6.0
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.9.0
# zipp                      3.23.0

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.5
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages
# Requires: certifi, charset_normalizer, idna, urllib3
# Required-by: jupyterlab_server

# %% [markdown]
# Inspect install location:

# %%
# !pip show requests | grep Location
# Out:
# Location: /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages

# %% [markdown]
# ## 3.5 Removing Packages

# %%
# !pip uninstall requests
# Out:
# Found existing installation: requests 2.32.5
# Uninstalling requests-2.32.5:
#   Would remove:
#     /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests-2.32.5.dist-info/*
#     /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/*
#   Would not remove (outside of prefix):
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/__init__.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/__version__.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/_internal_utils.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/adapters.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/api.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/auth.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/certs.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/compat.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/cookies.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/exceptions.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/help.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/hooks.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/models.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/packages.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/sessions.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/status_codes.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/structures.cpython-39.pyc
#     /Users/nicholasburczyk/Library/Caches/com.apple.python/Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages/requests/utils.cpython-39.pyc
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user

# %% [markdown]
# This deletes files from `site-packages`

# %% [markdown]
# ## 3.6 Requirements and Reproducibility
#
# Since it is bad practice to commit your environment directory, you need a way for other people to install your dependencies for your project.
#
# One of the ways to do this is with `requirements.txt` using `pip`.
#
# -----
#
# To capture dependencies:

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# Then if we want to install the requirements we run:

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: anyio==4.12.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (4.12.1)
# Requirement already satisfied: appnope==0.1.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (0.1.4)
# Requirement already satisfied: argon2-cffi==25.1.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (25.1.0)
# Requirement already satisfied: argon2-cffi-bindings==25.1.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (25.1.0)
# Requirement already satisfied: arrow==1.4.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (1.4.0)
# Requirement already satisfied: asttokens==3.0.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (3.0.1)
# Requirement already satisfied: async-lru==2.0.5 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (2.0.5)
# Requirement already satisfied: attrs==25.4.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (25.4.0)
# Requirement already satisfied: babel==2.18.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: beautifulsoup4==4.14.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (4.14.3)
# Requirement already satisfied: bleach==6.2.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (6.2.0)
# Requirement already satisfied: certifi==2026.1.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (2026.1.4)
# Requirement already satisfied: cffi==2.0.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (2.0.0)
# Requirement already satisfied: charset-normalizer==3.4.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (3.4.4)
# Requirement already satisfied: comm==0.2.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: debugpy==1.8.20 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (1.8.20)
# Requirement already satisfied: decorator==5.2.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (5.2.1)
# Requirement already satisfied: defusedxml==0.7.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 18)) (0.7.1)
# Requirement already satisfied: exceptiongroup==1.3.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: executing==2.2.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 20)) (2.2.1)
# Requirement already satisfied: fastjsonschema==2.21.2 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 21)) (2.21.2)
# Requirement already satisfied: fqdn==1.5.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 22)) (1.5.1)
# Requirement already satisfied: h11==0.16.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 23)) (0.16.0)
# Requirement already satisfied: httpcore==1.0.9 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (1.0.9)
# Requirement already satisfied: httpx==0.28.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 25)) (0.28.1)
# Requirement already satisfied: idna==3.11 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 26)) (3.11)
# Requirement already satisfied: importlib_metadata==8.7.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 27)) (8.7.1)
# Requirement already satisfied: ipykernel==6.31.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 28)) (6.31.0)
# Requirement already satisfied: ipython==8.18.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 29)) (8.18.1)
# Requirement already satisfied: isoduration==20.11.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 30)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 31)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.6 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 32)) (3.1.6)
# Requirement already satisfied: json5==0.13.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 33)) (0.13.0)
# Requirement already satisfied: jsonpointer==3.0.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 34)) (3.0.0)
# Requirement already satisfied: jsonschema==4.25.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 35)) (4.25.1)
# Requirement already satisfied: jsonschema-specifications==2025.9.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 36)) (2025.9.1)
# Requirement already satisfied: jupyter-events==0.12.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 37)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.3.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 38)) (2.3.0)
# Requirement already satisfied: jupyter_client==8.6.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 39)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.8.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 40)) (5.8.1)
# Requirement already satisfied: jupyter_server==2.17.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 41)) (2.17.0)
# Requirement already satisfied: jupyter_server_terminals==0.5.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 42)) (0.5.4)
# Requirement already satisfied: jupyterlab==4.5.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 43)) (4.5.3)
# Requirement already satisfied: jupyterlab_pygments==0.3.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 44)) (0.3.0)
# Requirement already satisfied: jupyterlab_server==2.28.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 45)) (2.28.0)
# Requirement already satisfied: lark==1.3.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 46)) (1.3.1)
# Requirement already satisfied: MarkupSafe==3.0.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 47)) (3.0.3)
# Requirement already satisfied: matplotlib-inline==0.2.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 48)) (0.2.1)
# Requirement already satisfied: mistune==3.2.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 49)) (3.2.0)
# Requirement already satisfied: nbclient==0.10.2 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 50)) (0.10.2)
# Requirement already satisfied: nbconvert==7.17.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 51)) (7.17.0)
# Requirement already satisfied: nbformat==5.10.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 52)) (5.10.4)
# Requirement already satisfied: nest-asyncio==1.6.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 53)) (1.6.0)
# Requirement already satisfied: notebook==7.5.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 54)) (7.5.3)
# Requirement already satisfied: notebook_shim==0.2.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 55)) (0.2.4)
# Requirement already satisfied: overrides==7.7.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 56)) (7.7.0)
# Requirement already satisfied: packaging==26.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 57)) (26.0)
# Requirement already satisfied: pandocfilters==1.5.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 58)) (1.5.1)
# Requirement already satisfied: parso==0.8.6 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 59)) (0.8.6)
# Requirement already satisfied: pexpect==4.9.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 60)) (4.9.0)
# Requirement already satisfied: platformdirs==4.4.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 61)) (4.4.0)
# Requirement already satisfied: prometheus_client==0.24.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 62)) (0.24.1)
# Requirement already satisfied: prompt_toolkit==3.0.52 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 63)) (3.0.52)
# Requirement already satisfied: psutil==7.2.2 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 64)) (7.2.2)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 65)) (0.7.0)
# Requirement already satisfied: pure_eval==0.2.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 66)) (0.2.3)
# Requirement already satisfied: pycparser==2.23 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 67)) (2.23)
# Requirement already satisfied: Pygments==2.19.2 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 68)) (2.19.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 69)) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==4.0.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 70)) (4.0.0)
# Requirement already satisfied: PyYAML==6.0.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 71)) (6.0.3)
# Requirement already satisfied: pyzmq==27.1.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 72)) (27.1.0)
# Requirement already satisfied: referencing==0.36.2 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 73)) (0.36.2)
# Requirement already satisfied: requests==2.32.5 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 74)) (2.32.5)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 75)) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 76)) (0.1.1)
# Requirement already satisfied: rfc3987-syntax==1.1.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 77)) (1.1.0)
# Requirement already satisfied: rpds-py==0.27.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 78)) (0.27.1)
# Requirement already satisfied: Send2Trash==2.1.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 79)) (2.1.0)
# Requirement already satisfied: six==1.17.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 80)) (1.17.0)
# Requirement already satisfied: soupsieve==2.8.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 81)) (2.8.3)
# Requirement already satisfied: stack-data==0.6.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 82)) (0.6.3)
# Requirement already satisfied: terminado==0.18.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 83)) (0.18.1)
# Requirement already satisfied: tinycss2==1.4.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 84)) (1.4.0)
# Requirement already satisfied: tomli==2.4.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 85)) (2.4.0)
# Requirement already satisfied: tornado==6.5.4 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 86)) (6.5.4)
# Requirement already satisfied: traitlets==5.14.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 87)) (5.14.3)
# Requirement already satisfied: typing_extensions==4.15.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 88)) (4.15.0)
# Requirement already satisfied: tzdata==2025.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 89)) (2025.3)
# Requirement already satisfied: uri-template==1.3.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 90)) (1.3.0)
# Requirement already satisfied: urllib3==2.6.3 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 91)) (2.6.3)
# Requirement already satisfied: wcwidth==0.6.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 92)) (0.6.0)
# Requirement already satisfied: webcolors==24.11.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 93)) (24.11.1)
# Requirement already satisfied: webencodings==0.5.1 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 94)) (0.5.1)
# Requirement already satisfied: websocket-client==1.9.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 95)) (1.9.0)
# Requirement already satisfied: zipp==3.23.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from -r requirements.txt (line 96)) (3.23.0)
# Requirement already satisfied: setuptools>=41.1.0 in /Users/nicholasburczyk/Desktop/CS_CLASS/Python Fundamentals/venv/lib/python3.9/site-packages (from jupyterlab==4.5.3->-r requirements.txt (line 43)) (44.1.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
